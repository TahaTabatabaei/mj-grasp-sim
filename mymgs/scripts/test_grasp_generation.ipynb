# %% [markdown]
# ### grasp genration: robotiq_2f_85
# make a new file with this commadn: \
# `python -m mgs.cli.gen_grasps gripper=robotiq_2f_85`
#
# find the output (a compressed .npz file) in the uotput folder (/mj-grasp-sim/mymgs)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('/home/tahaos/Code/Projects/mj-grasp-sim/mymgs/MGS_OUTPUT_DIR/Cube_Pad_628e53fd7c9ddb43a6adb9a32d4991bf.npz')

# %%
print(data.files)
# Out:
# ['gripper_transform', 'grasps', 'object_id', 'gripper']

# %%
gripper_transform = data['gripper_transform']
print(gripper_transform.shape)
print(gripper_transform)

# gripper_transform: A pose transformation (position + orientation) from the gripper’s base to its contact frame.
# Out:
# (7,)
# [ 0.    0.   -0.15  1.    0.    0.    0.  ]

# %%
grasps = data['grasps']
print(grasps.shape)

# grasps: List of N (10 in this case) valid grasp poses 

for i in range(grasps.shape[0]):
    print(grasps[i])
# Out:
# (10, 7)
# [ 0.01548437  0.04520778  0.025       0.65390843 -0.3258481  -0.5716835
#  -0.37336937]
# [-0.01317336  0.0443389   0.01555046 -0.41036594  0.6861162   0.46609116
#   0.37895042]
# [ 0.00206984  0.04503657  0.00944182 -0.14491     0.7409101   0.41088772
#   0.51110137]
# [-0.01318668  0.025       0.0204303   0.45852923  0.65195435  0.46412998
#   0.38638034]
# [ 0.          0.01422962  0.01897818 -0.02177629 -0.1901102   0.97866446
#   0.07483177]
# [ 0.02004819  0.025       0.04161146  0.69535875  0.02552835 -0.22015937
#  -0.6836332 ]
# [ 0.00627251  0.0219752   0.025       0.81291795 -0.24278197 -0.5170536
#  -0.11347628]
# [ 0.00198639  0.045527    0.025       0.7718535  -0.07011329 -0.6266823
#  -0.08121317]
# [ 0.          0.01801708  0.01323836  0.9831729   0.13676414  0.00147224
#  -0.12109673]
# [ 0.01795309  0.025       0.02769119  0.73877     0.19953339  0.06450593
#  -0.6405031 ]

# %%
obj_id = data['object_id']
print(obj_id.shape)
print(obj_id)

# object_id: The ID or name of the object for which the grasps were generated.
# Out:
# ()
# Cube_Pad

# %%
gripper = data['gripper']
print(gripper.shape)
print(gripper)

# gripper: The name of the gripper used.
# Out:
# ()
# Robotiq2f85Gripper

# %%
# for every directory name inside /home/tahaos/Code/Projects/mj-grasp-sim/asset/mj-objects/YCB
# run the following command to run this script(/home/tahaos/Code/Projects/mj-grasp-sim/mgs/cli/gen_grasps.py):

# python -m mgs.cli.gen_grasps gripper=robotiq_2f_85 object_id={directoryname}
# Example command to generate grasps for a specific object:
# python -m mgs.cli.gen_grasps gripper=robotiq_2f_85 object_id=011_banana
import os
import subprocess

# Path to the YCB objects directory
# ycb_dir = "/home/tahaos/Code/Projects/mj-grasp-sim/asset/mj-objects/YCB"

# List all directories (object IDs) in the YCB folder
object_ids = [d for d in os.listdir(ycb_dir) if os.path.isdir(os.path.join(ycb_dir, d))]

# Path to the grasp generation script
gen_grasps_script = "/home/tahaos/Code/Projects/mj-grasp-sim/mgs/cli/gen_grasps.py"

# Loop through each object and run the grasp generation command
for obj_id in object_ids:
    cmd = [
        "python", f"{gen_grasps_script}",
        "gripper=robotiq_2f_85",
        f"object_id={obj_id}"
    ]
    print(f"Running: {' '.join(cmd)}")
    subprocess.run(cmd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 14
#       8 import subprocess
#      10 # Path to the YCB objects directory
#      11 # ycb_dir = "/home/tahaos/Code/Projects/mj-grasp-sim/asset/mj-objects/YCB"
#      12
#      13 # List all directories (object IDs) in the YCB folder
# ---> 14 object_ids = [d for d in os.listdir(ycb_dir) if os.path.isdir(os.path.join(ycb_dir, d))]
#      16 # Path to the grasp generation script
#      17 gen_grasps_script = "/home/tahaos/Code/Projects/mj-grasp-sim/mgs/cli/gen_grasps.py"
#
# NameError: name 'ycb_dir' is not defined
